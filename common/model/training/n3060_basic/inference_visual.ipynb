# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
import seaborn

# read in the data and establish the headers
headers = [
    "pred",
    "mean_0",
    "mean_1",
    "mean_2",
    "var_0",
    "var_1",
    "var_2",
    "kurt_0",
    "kurt_1",
    "kurt_2",
    "skew_0",
    "skew_1",
    "skew_2",
    "mfcc_0",
    "mfcc_1",
    "mfcc_2",
    "mfcc_3",
    "mfcc_4",
    "mfcc_5",
    "mfcc_6",
    "mfcc_7",
    "mfcc_8",
    "mfcc_9"
]
data_path = "inference_results.csv"
df = pd.read_csv(data_path,
                names=headers)
# add the actual result
df["true"] = 0
df.loc[(df.index>=6915)&(df.index<6935),"true"] = 1
df.describe()
# Out:
#               pred       mean_0       mean_1       mean_2         var_0  \
# count  8996.000000  8996.000000  8996.000000  8996.000000   8996.000000
# mean      0.432277    -0.275675    -0.308457    -0.341285      2.658109
# std       0.088836     8.466288     8.817527     8.954603    265.697252
# min       0.087171    -6.862926    -7.199744    -7.226778     -3.104019
# 25%       0.370449    -1.013701    -1.002974    -1.052298     -0.812754
# 50%       0.431533    -0.449278    -0.524383    -0.534766     -0.035050
# 75%       0.492303     0.132203     0.083067     0.056219      0.514749
# max       1.000000   798.194247   831.820274   845.001950  25200.347653
#
#               var_1         var_2       kurt_0       kurt_1       kurt_2  ...  \
# count   8996.000000   8996.000000  8996.000000  8996.000000  8996.000000  ...
# mean       2.330489      3.139367     0.113443     0.123954     0.176163  ...
# std      237.202581    315.354501     0.952462     0.954398     0.946088  ...
# ...

# %%
df.loc[:,["pred", "true"]].plot.line()

# %%
df.loc[(df.index>=6750)&(df.index<7000),["pred", "true"]].plot.line()

# %%
df.loc[(df.index>=6750)&(df.index<7000),["skew_0", "true"]].plot.line()

# %%
df.loc[(df.index>=6750)&(df.index<7000),["kurt_2", "true"]].plot.line()

# %%
df.loc[(df.index>=6750)&(df.index<8000),df.columns[1:]].plot.line(figsize=(10,10))
plt.legend(loc="upper right")

# %%
df.loc[(df.index>=6750)&(df.index<8000),["var_0", "true"]].plot.line(figsize=(10,10))
plt.legend(loc="upper right")

# %%
df.loc[(df.index>=6750)&(df.index<8000),df.columns[13:]].plot.line(figsize=(10,10))
plt.legend(loc="upper right")

# %%
df.loc[(df.index>=6750)&(df.index<8000),["mfcc_2", "true"]].plot.line(figsize=(10,10))
plt.legend(loc="upper right")
